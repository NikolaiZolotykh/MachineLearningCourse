# %% [markdown]
# ![Python logo](Python_logo_and_wordmark.svg)
#
# [Python](http://www.python.org) (Питон, Пайтон) – высокоуровневый язык программирования общего назначения.
#
# Поддерживает несколько парадигм программирования (структурное, объектно-ориентированное,
# функциональное и др.)
#
# Основные черты:
#
# * Динамическая типизация (тип переменной определяется во время выполнения и может меняться в процессе работы программы)
# * Автоматическое управление памятью
# * Интроспекция (возможность получения информации об объекте)
# * Обработка исключений
# * Поддержка многопоточных вычислений
# * Высокоуровневые структуры данных
#
# Код организуется в функции и классы, которые, в свою очередь, могут быть организованы в модули, а те - в пакеты.
#
# Некоторые популярные реализации Питона:
#
# * [CPython](https://github.com/python/cpython)
# * [IronPython](http://ironpython.net/)
# * [Jython](http://www.jython.org/)
# * [PyPy](http://pypy.org/)
# * ...
#
# Интерпретаторы Питона позволяют использовать его в интерактивном режиме.
#
# Другие важные черты:
#
# * Многоплатформенный (Microsoft Windows, все варианты UNIX, Mac OS, Symbian, ...)
# * Свободно распространяемый, с открытым кодом
# * Богатая стандартная библиотека (работа с операционной системой, сетевыми протоколами и форматами интернета, XML, регулярными выражениями, мультимедийными форматами, криптогшрафическими протоколами, архивами, . . . )
# * Огромное количество дополнительных библиотек (веб, базы данных, обработка изображений, обработка текста, численные методы, системные вызовы, графика, разработка игр, ...)
# * Программный интерфейс для написания собственных модулей на C и C++
# * Возможность встраивания интерпретатора python в приложения
#
# Появился в 1990 г. (по другим источникам – 1991 г.)
#
# Автор: _Гвидо ван Россум_ (_Guido van Rossum_)
#
# Последние релизы:
#
# * python 3.x.x
# * python 2.x.x
#
# Ветки 2.x и 3.x не совместимы.
#
# Имеется утилита `2to3`.
#
# Мы будем работать с версией 3.x.
#
# Основные области использования Питона:
#
# * Интеграция приложений (скрипты)
# * Создание прототипов
# * Научные вычисления
# * Веб-приложения
# * ...
#
# Питон интенсивно используется в компаниях и организациях:
#
# * Google
# * Яndex
# * Apple
# * NASA
# * CERN
# * Nokia
# * DreamWorks
# * ...
#
# ## TIOBE Index
#
# [Programming Languages TIOBE Index](http://www.tiobe.com/tiobe-index/)

# %% [markdown]
# ## SciPy ecosystem
#
# * `NumPy` – многомерные массивы, линейная алгебра и т.д.
# * `SciPy` – численные методы (дифференциальные уравнения, оптимизация и т.д.)
# * `Matplotlib` (включая модуль `PyLab`) – научная графика
# * `IPython` – оболочка для интерактивных вычислений
# * `SymPy` – символьные вычисления
# * `Pandas` – анализ данных
#
# ## Другие полезные библиотеки
#
# * `Scikit-Learn` – машинное обучение
# * `Scikit-Image` – обработка изображений
# * `OpenCV` – компьютерное зрение
# * `NLTK` – обработка естественного языка
#
# Все библиотеки и программы, перечисленные в двух списках выше, (кроме `OpenCV`) уже есть в дистрибутиве `Anaconda`.

# %% [markdown]
# ## IPython
#
# `IPython` (Férnando Pérez) – оболочка для выполнения интерактивных вычислений (поддерживает разные языки)
#
# * Терминал или Qt-консоль
# * Расширенная интроспекция
# * Поддержка параллельного программирования
# * IPython (Jupyter) Notebook: Markdown-language, математические выражения, встраиваемые графика, медиа
